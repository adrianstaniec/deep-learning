# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
words[:20]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english']

# %%
int_words[:20]
# Out:
# [5234,
#  3082,
#  11,
#  5,
#  194,
#  1,
#  3136,
#  45,
#  58,
#  155,
#  127,
#  741,
#  476,
#  10596,
#  133,
#  0,
#  27494,
#  1,
#  0,
#  102]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
count = {w: 0 for w in set(int_words)}
for w in int_words:
    count[w] += 1
list(count.items())[:20]
# Out:
# [(0, 1061396),
#  (1, 593677),
#  (2, 416629),
#  (3, 411764),
#  (4, 372201),
#  (5, 325873),
#  (6, 316376),
#  (7, 264975),
#  (8, 250430),
#  (9, 192644),
#  (10, 183153),
#  (11, 131815),
#  (12, 125285),
#  (13, 118445),
#  (14, 116710),
#  (15, 115789),
#  (16, 114775),
#  (17, 112807),
#  (18, 111831),
#  (19, 109510)]

# %%
t = 10**-5
total = len(int_words)
prob = {}
for key, val in count.items():
    prob[key] = (1 - np.sqrt(t / (val/total) ))
list(prob.items())[:20]
# Out:
# [(0, 0.98746376577740469),
#  (1, 0.98323781193133519),
#  (2, 0.97999073790717206),
#  (3, 0.9798728800896066),
#  (4, 0.97883018546630463),
#  (5, 0.97737536238795875),
#  (6, 0.97703829909505446),
#  (7, 0.9749098434772655),
#  (8, 0.97419150710880509),
#  (9, 0.97057421364733043),
#  (10, 0.96982141987906356),
#  (11, 0.9644267615025448),
#  (12, 0.96351147714751806),
#  (13, 0.96247268826339005),
#  (14, 0.96219477853599333),
#  (15, 0.96204472263650453),
#  (16, 0.96187743001877457),
#  (17, 0.96154632989244049),
#  (18, 0.96137889308882907),
#  (19, 0.96097176318217992)]

# %%
train_words = [w for w in int_words if np.random.rand() > prob[w]]
train_words[:20]
# Out:
# [58,
#  741,
#  10596,
#  27494,
#  854,
#  15104,
#  61877,
#  3584,
#  10717,
#  2732,
#  1423,
#  2759,
#  686,
#  7094,
#  5234,
#  320,
#  248,
#  45139,
#  5234,
#  1134]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(0, window_size) + 1
    left_side = words[max(0, idx - R) : idx]
    right_side = words[idx + 1 : min(idx + R, len(words))]
    return list(set(left_side + right_side))

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 100 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))  # embedding weight matrix
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding])) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b,
                                      labels, embed, 
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 13.0678 0.0188 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 12.9446 0.0155 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 12.7313 0.0155 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 12.7422 0.0153 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 12.5142 0.0156 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 12.5022 0.0153 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 12.4231 0.0154 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 12.2777 0.0153 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 12.1878 0.0154 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 12.1043 0.0152 sec/batch
# Nearest to often: plebeians, potok, malfunction, spader, chair, oldest, schuster, sundry,
# Nearest to time: freemason, mbps, ferry, zombies, appetites, villas, statism, guerrero,
# Nearest to has: inanimate, alen, recalled, bolognese, unheard, subordinated, soliloquy, halicarnassus,
# Nearest to during: tiresias, drogo, jizya, titans, tool, beatnik, vegas, blastula,
# Nearest to an: dzogchen, blanks, voyages, sociological, peg, whetstone, hammurabi, silvestris,
# Nearest to may: ud, embroidery, harrell, synoptics, esophagus, randomization, legalisation, godless,
# Nearest to as: outselling, ennead, germaine, warhol, bassoons, orkney, restricting, lesh,
# Nearest to have: woken, tefan, drawers, blackened, remixing, subfamilia, mechanic, isabela,
# Nearest to mathematics: differ, carib, postseason, tuireann, wrongdoing, normal, archer, preconceptions,
# Nearest to bbc: minorities, sua, semen, anthropomorphism, ryukyu, marking, codata, multilingual,
# Nearest to bible: signifier, otho, dockyard, vocations, grams, realignment, manar, editions,
# Nearest to running: aught, multiparty, andreotti, rastafarians, jammu, decomposition, vasili, biometric,
# Nearest to event: luf, hecuba, graecorum, pitches, incline, calves, tabs, reston,
# Nearest to freedom: aleksandra, tabu, micheal, methodius, skip, clap, bunyan, telomerase,
# Nearest to pressure: provability, probabilities, aspires, quips, bonham, xb, nash, successors,
# Nearest to stage: immunocompromised, zalta, australian, encodings, grittier, frightening, pun, mujibur,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 12.0160 0.0165 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 11.8911 0.0156 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 11.7984 0.0155 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 11.6302 0.0155 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 11.6239 0.0156 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 11.5036 0.0154 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 11.4453 0.0153 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 11.3174 0.0154 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 11.2283 0.0153 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 11.1707 0.0153 sec/batch
# Nearest to often: plebeians, potok, malfunction, sundry, spader, oldest, chair, orycteropus,
# Nearest to time: freemason, ferry, mbps, zombies, guerrero, dirham, villas, diger,
# Nearest to has: inanimate, recalled, halicarnassus, bolognese, individually, quorum, pigmented, alen,
# Nearest to during: tiresias, titans, jizya, tool, cuny, drogo, beatnik, vegas,
# Nearest to an: dzogchen, blanks, sociological, voyages, peg, whetstone, silvestris, hammurabi,
# Nearest to may: ud, embroidery, synoptics, harrell, esophagus, randomization, legalisation, godless,
# Nearest to as: outselling, ennead, germaine, warhol, restricting, kind, bassoons, orkney,
# Nearest to have: woken, tefan, blackened, drawers, stricter, turtles, isabela, wizards,
# Nearest to mathematics: differ, wrongdoing, tuireann, carib, postseason, preconceptions, archer, butterworth,
# Nearest to bbc: minorities, sua, anthropomorphism, semen, ryukyu, multilingual, marking, configured,
# Nearest to bible: signifier, dockyard, otho, editions, realignment, vocations, grams, manar,
# Nearest to running: aught, multiparty, andreotti, jammu, decomposition, rastafarians, fecal, biometric,
# Nearest to event: luf, graecorum, hecuba, pitches, incline, tabs, reston, calves,
# Nearest to freedom: aleksandra, tabu, methodius, micheal, telomerase, attic, romeo, skip,
# Nearest to pressure: probabilities, provability, aspires, quips, bonham, nash, carcassi, ffff,
# Nearest to stage: immunocompromised, zalta, encodings, grittier, pun, australian, frightening, description,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 11.0975 0.0162 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 10.9967 0.0153 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 10.9208 0.0154 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 10.7941 0.0153 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 10.7214 0.0153 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 10.6021 0.0155 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 10.5802 0.0154 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 10.4955 0.0153 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 10.3959 0.0156 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 10.2916 0.0154 sec/batch
# Nearest to often: plebeians, potok, sundry, malfunction, schuster, oldest, chair, orycteropus,
# Nearest to time: freemason, ferry, zombies, guerrero, mbps, intellectually, hoax, statism,
# Nearest to has: inanimate, recalled, individually, soliloquy, halicarnassus, alen, particulars, pigmented,
# Nearest to during: titans, tiresias, jizya, drogo, tool, cuny, vegas, beatnik,
# Nearest to an: voyages, blanks, dzogchen, sociological, whetstone, petrovi, hammurabi, thicknesses,
# Nearest to may: ud, embroidery, synoptics, harrell, legalisation, esophagus, devoiced, randomization,
# Nearest to as: outselling, ennead, warhol, restricting, library, lesh, germaine, quarrelled,
# Nearest to have: woken, blackened, plesiosaurs, turtles, tefan, stricter, annoyed, mechanic,
# Nearest to mathematics: differ, tuireann, wrongdoing, preconceptions, postseason, carib, archer, hegelians,
# Nearest to bbc: minorities, semen, sua, anthropomorphism, ryukyu, multilingual, codata, encapsulated,
# Nearest to bible: signifier, dockyard, editions, otho, realignment, vocations, isabelle, orser,
# Nearest to running: aught, multiparty, decomposition, andreotti, rastafarians, carved, shastri, biometric,
# Nearest to event: luf, graecorum, hecuba, pitches, incline, tabs, calves, reston,
# Nearest to freedom: aleksandra, tabu, telomerase, clap, attic, skip, methodius, romeo,
# Nearest to pressure: probabilities, provability, aspires, quips, nash, bonham, ffff, carcassi,
# Nearest to stage: immunocompromised, zalta, encodings, grittier, parke, description, frightening, australian,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 10.2486 0.0163 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 10.1468 0.0155 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 10.0632 0.0155 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 10.0226 0.0153 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 9.9473 0.0155 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 9.8883 0.0154 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 9.8173 0.0154 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 9.7875 0.0153 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 9.6660 0.0153 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 9.6200 0.0154 sec/batch
# Nearest to often: plebeians, sundry, potok, malfunction, oldest, orycteropus, schuster, chair,
# Nearest to time: freemason, ferry, guerrero, villas, dirham, statism, appetites, duels,
# Nearest to has: inanimate, recalled, clare, soliloquy, dagbladet, magi, particulars, halicarnassus,
# Nearest to during: tiresias, drogo, titans, cuny, tool, kind, postmodernism, bipartisan,
# Nearest to an: sociological, whetstone, petrovi, mercantile, thicknesses, dzogchen, marshal, hammurabi,
# Nearest to may: ud, embroidery, synoptics, harrell, legalisation, guns, subtitles, gpa,
# Nearest to as: the, warhol, homophones, erin, library, pickle, to, quarrelled,
# Nearest to have: plesiosaurs, tefan, woken, billionaires, latencies, blackened, gateless, mechanic,
# Nearest to mathematics: differ, wrongdoing, tuireann, carib, preconceptions, prodi, archer, postseason,
# Nearest to bbc: minorities, semen, sua, ryukyu, anthropomorphism, marking, codata, multilingual,
# Nearest to bible: signifier, dockyard, otho, editions, vocations, realignment, manar, isabelle,
# Nearest to running: aught, multiparty, jammu, rastafarians, andreotti, decomposition, biometric, thirds,
# Nearest to event: luf, graecorum, hecuba, pitches, incline, reston, tabs, meaninglessness,
# Nearest to freedom: aleksandra, tabu, attic, telomerase, skip, codings, micheal, methodius,
# Nearest to pressure: probabilities, provability, aspires, nash, quips, carcassi, ffff, bonham,
# Nearest to stage: immunocompromised, parke, frightening, grittier, zalta, pun, mujibur, encodings,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 9.6097 0.0163 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 9.4513 0.0153 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 9.3945 0.0155 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 9.3682 0.0158 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 9.2955 0.0155 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 9.2128 0.0154 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 9.1215 0.0118 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 9.1183 0.0155 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 8.9635 0.0154 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 8.9660 0.0153 sec/batch
# Nearest to often: plebeians, orycteropus, potok, schuster, sundry, malfunction, oldest, br,
# Nearest to time: freemason, mons, hiiumaa, ferry, hoax, guerrero, statism, dirham,
# Nearest to has: the, former, inanimate, to, for, wittenberg, escaped, by,
# Nearest to during: a, and, to, the, as, is, drogo, in,
# Nearest to an: in, zero, a, the, to, by, cristobal, as,
# Nearest to may: embroidery, ud, ige, guns, devoiced, subtitles, levite, synoptics,
# Nearest to as: the, a, to, in, by, of, and, is,
# Nearest to have: in, an, to, a, by, accordingly, as, the,
# Nearest to mathematics: differ, wrongdoing, tuireann, prodi, foodborne, preconceptions, carib, archer,
# Nearest to bbc: minorities, semen, anthropomorphism, ryukyu, sua, codata, encapsulated, multilingual,
# Nearest to bible: signifier, otho, dockyard, editions, manar, vocations, twist, realignment,
# Nearest to running: aught, multiparty, rastafarians, jammu, andreotti, fecal, biometric, carved,
# Nearest to event: luf, graecorum, hecuba, pitches, incline, tabs, norouz, calves,
# Nearest to freedom: aleksandra, tabu, attic, telomerase, methodius, skip, micheal, contingency,
# Nearest to pressure: probabilities, provability, aspires, nash, quips, laconia, carcassi, ffff,
# Nearest to stage: immunocompromised, frightening, encodings, brig, parke, iole, grittier, pun,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 8.9238 0.0163 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 8.8484 0.0153 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 8.7374 0.0155 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 8.7499 0.0153 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 8.6643 0.0155 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 8.6092 0.0153 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 8.4829 0.0154 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 8.4418 0.0154 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 8.4192 0.0153 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 8.3632 0.0151 sec/batch
# Nearest to often: plebeians, period, to, during, sangre, of, the, municipal,
# Nearest to time: that, of, to, from, for, was, s, have,
# Nearest to has: to, the, of, in, is, as, this, for,
# Nearest to during: to, is, in, of, that, they, it, as,
# Nearest to an: in, have, that, the, is, a, as, to,
# Nearest to may: is, most, that, it, on, s, but, the,
# Nearest to as: in, the, to, is, of, it, that, and,
# Nearest to have: to, in, that, the, are, of, as, an,
# Nearest to mathematics: differ, wrongdoing, tuireann, foodborne, normal, hco, mobster, preconceptions,
# Nearest to bbc: minorities, semen, anthropomorphism, ryukyu, sua, codata, marking, encapsulated,
# Nearest to bible: signifier, otho, manar, dockyard, vocations, editions, isabelle, orser,
# Nearest to running: aught, multiparty, jammu, decomposition, carved, acceleration, rastafarians, berserker,
# Nearest to event: luf, graecorum, hecuba, incline, calves, anthroposophical, tabs, meaninglessness,
# Nearest to freedom: aleksandra, tabu, angli, micheal, telomerase, contingency, clap, methodius,
# Nearest to pressure: probabilities, provability, nash, quips, aspires, carcassi, mccormick, laconia,
# Nearest to stage: pun, immunocompromised, zalta, frightening, parke, encodings, meetings, grittier,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 8.3609 0.0162 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 8.1836 0.0152 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 8.1965 0.0152 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 8.1293 0.0152 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 8.1451 0.0152 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 8.0643 0.0152 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 7.9463 0.0153 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 7.9144 0.0152 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 7.9021 0.0152 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 7.8134 0.0152 sec/batch
# Nearest to often: have, which, that, the, as, of, first, a,
# Nearest to time: was, on, and, to, from, or, between, in,
# Nearest to has: of, s, the, not, but, in, with, that,
# Nearest to during: the, of, zero, and, first, s, for, on,
# Nearest to an: the, in, to, of, that, it, not, with,
# Nearest to may: there, of, that, s, which, is, a, the,
# Nearest to as: a, to, with, it, the, be, which, but,
# Nearest to have: is, for, that, or, are, to, which, of,
# Nearest to mathematics: differ, wrongdoing, tuireann, foodborne, preconceptions, mobster, disruptive, hco,
# Nearest to bbc: minorities, semen, anthropomorphism, sua, codata, ryukyu, marking, encapsulated,
# Nearest to bible: manar, signifier, otho, dockyard, vocations, implant, editions, isabelle,
# Nearest to running: aught, carved, acceleration, decomposition, rastafarians, jammu, fecal, shastri,
# Nearest to event: luf, hecuba, graecorum, anthroposophical, incline, national, calves, meaninglessness,
# Nearest to freedom: aleksandra, angli, same, micheal, tabu, dropped, contingency, attic,
# Nearest to pressure: probabilities, provability, quips, carcassi, nash, mccormick, freenode, laconia,
# Nearest to stage: pun, immunocompromised, frightening, zalta, baroque, grittier, parke, encodings,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 7.8820 0.0162 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 7.7341 0.0152 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 7.6347 0.0151 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 7.7158 0.0152 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 7.6842 0.0152 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 7.5849 0.0153 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 7.5802 0.0153 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 7.5598 0.0152 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 7.4035 0.0153 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 7.4207 0.0151 sec/batch
# Nearest to often: be, are, this, that, some, not, and, have,
# Nearest to time: s, or, the, that, from, there, this, with,
# Nearest to has: as, in, and, that, the, a, is, or,
# Nearest to during: in, to, the, from, and, of, by, s,
# Nearest to an: or, that, in, the, to, and, as, it,
# Nearest to may: or, not, to, that, the, it, is, and,
# Nearest to as: the, in, to, of, and, has, for, an,
# Nearest to have: a, to, that, not, the, this, and, as,
# Nearest to mathematics: differ, foodborne, tuireann, preconceptions, wrongdoing, hco, mobster, hegelians,
# Nearest to bbc: minorities, semen, anthropomorphism, sua, ryukyu, codata, trisha, encapsulated,
# Nearest to bible: signifier, manar, otho, dockyard, vocations, departments, stink, implant,
# Nearest to running: rastafarians, decomposition, shastri, aught, acceleration, concern, astute, apocalypticism,
# Nearest to event: national, luf, western, graecorum, other, hecuba, barbuda, calves,
# Nearest to freedom: aleksandra, same, angli, telomerase, book, attic, made, micheal,
# Nearest to pressure: probabilities, provability, freenode, operates, carcassi, laconia, somewhat, karlsson,
# Nearest to stage: pun, baroque, immunocompromised, parke, frightening, meetings, grittier, encodings,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 7.3101 0.0160 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 7.4628 0.0153 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 7.3605 0.0153 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 7.3374 0.0153 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 7.3151 0.0152 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 7.1413 0.0152 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 7.2699 0.0150 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 7.1630 0.0151 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 7.1162 0.0152 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 7.0814 0.0150 sec/batch
# Nearest to often: be, is, as, or, number, a, before, made,
# Nearest to time: to, by, a, the, and, was, for, as,
# Nearest to has: is, a, the, on, from, be, to, in,
# Nearest to during: by, and, its, the, over, would, were, to,
# Nearest to an: is, or, has, that, the, of, and, as,
# Nearest to may: be, about, or, is, as, so, to, a,
# Nearest to as: the, in, all, of, for, by, not, from,
# Nearest to have: is, are, as, not, a, be, of, to,
# Nearest to mathematics: differ, tuireann, mobster, preconceptions, foodborne, wrongdoing, hco, samarkand,
# Nearest to bbc: minorities, semen, anthropomorphism, codata, trisha, sua, sceptical, ryukyu,
# Nearest to bible: signifier, otho, manar, implant, stink, isabelle, vocations, kinds,
# Nearest to running: nutrient, astute, ministry, apocalypticism, acceleration, quarrel, concern, multiparty,
# Nearest to event: people, luf, few, some, important, western, with, particular,
# Nearest to freedom: also, february, in, name, his, never, state, held,
# Nearest to pressure: provability, probabilities, frequently, laconia, operates, freenode, successors, low,
# Nearest to stage: called, grittier, more, pun, far, introduced, other, gibson,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 7.0839 0.0160 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 7.0753 0.0153 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 7.0134 0.0081 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 6.9805 0.0151 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 6.9196 0.0151 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 6.9132 0.0153 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 6.8764 0.0150 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 6.8602 0.0151 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 6.7954 0.0152 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 6.7264 0.0152 sec/batch
# Nearest to often: more, to, has, some, is, there, which, a,
# Nearest to time: to, the, in, is, it, being, of, only,
# Nearest to has: to, have, as, other, the, of, with, this,
# Nearest to during: on, of, in, to, by, later, government, became,
# Nearest to an: to, or, the, of, being, that, as, according,
# Nearest to may: only, being, is, of, that, a, as, the,
# Nearest to as: of, to, a, the, in, was, most, this,
# Nearest to have: in, to, the, has, this, that, of, be,
# Nearest to mathematics: differ, tuireann, normal, wrongdoing, mobster, foodborne, samarkand, preconceptions,
# Nearest to bbc: minorities, semen, anthropomorphism, sceptical, beckton, temporarily, codata, merck,
# Nearest to bible: manar, kinds, signifier, stink, departments, otho, studying, combining,
# Nearest to running: name, kingdom, state, in, ministry, world, again, note,
# Nearest to event: only, well, view, lost, by, in, few, to,
# Nearest to freedom: state, received, national, was, distinct, house, named, whether,
# Nearest to pressure: get, came, just, greater, group, so, operates, heavily,
# Nearest to stage: entire, far, place, by, although, does, way, modern,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 6.7352 0.0161 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 6.7219 0.0151 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 6.6350 0.0151 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 6.5239 0.0152 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 6.5512 0.0151 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 6.5598 0.0150 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 6.6533 0.0150 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 6.5054 0.0150 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 6.4258 0.0150 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 6.4872 0.0151 sec/batch
# Nearest to often: is, the, be, with, it, no, to, are,
# Nearest to time: the, when, to, a, most, and, in, by,
# Nearest to has: and, to, of, not, the, a, but, in,
# Nearest to during: and, war, the, in, after, to, from, by,
# Nearest to an: it, for, the, is, a, more, out, as,
# Nearest to may: is, to, it, a, by, no, there, of,
# Nearest to as: the, to, a, in, is, and, for, of,
# Nearest to have: of, are, a, or, is, it, the, for,
# Nearest to mathematics: differ, shot, highly, normal, tuireann, wrongdoing, explicitly, samarkand,
# Nearest to bbc: minorities, beckton, semen, merck, temporarily, immigrating, anthropomorphism, codata,
# Nearest to bible: departments, manar, kinds, stink, combines, basics, editions, signifier,
# Nearest to running: because, so, through, just, go, set, created, third,
# Nearest to event: each, much, a, no, among, makes, few, its,
# Nearest to freedom: when, since, government, whether, state, first, the, in,
# Nearest to pressure: mostly, get, while, heavily, over, strong, remains, out,
# Nearest to stage: entire, world, some, made, to, same, or, more,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 6.4924 0.0162 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 6.4422 0.0151 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 6.3096 0.0151 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 6.3571 0.0152 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 6.3889 0.0151 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 6.2650 0.0152 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 6.3025 0.0151 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 6.3207 0.0150 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 6.1311 0.0151 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 6.2457 0.0151 sec/batch
# Nearest to often: be, or, this, but, as, to, have, with,
# Nearest to time: the, and, in, on, of, it, for, some,
# Nearest to has: the, in, and, as, to, a, which, this,
# Nearest to during: and, countries, with, was, from, the, of, in,
# Nearest to an: because, and, be, if, on, the, a, to,
# Nearest to may: to, not, which, even, for, are, be, this,
# Nearest to as: it, this, be, to, the, of, are, in,
# Nearest to have: this, a, be, the, that, are, is, has,
# Nearest to mathematics: differ, explicitly, view, now, removed, shot, decided, recognized,
# Nearest to bbc: domination, minorities, equivalent, semen, beckton, unicameral, temporarily, marking,
# Nearest to bible: departments, basics, editions, kinds, conversely, chairman, gaining, virtually,
# Nearest to running: own, through, by, been, since, each, great, could,
# Nearest to event: following, the, about, still, those, few, large, of,
# Nearest to freedom: some, has, state, it, in, to, on, with,
# Nearest to pressure: out, thus, while, know, are, heavily, power, living,
# Nearest to stage: that, be, many, and, writing, each, its, it,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 6.2503 0.0161 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 6.1013 0.0153 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 6.1809 0.0152 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 6.1382 0.0153 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 6.1060 0.0152 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 6.0529 0.0153 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 6.0021 0.0152 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 6.1324 0.0152 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 6.0820 0.0153 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 6.0530 0.0152 sec/batch
# Nearest to often: be, are, as, but, these, or, all, is,
# Nearest to time: on, a, it, the, of, and, from, or,
# Nearest to has: to, it, not, is, are, and, have, for,
# Nearest to during: the, in, to, from, by, countries, on, and,
# Nearest to an: for, not, to, this, as, is, that, it,
# Nearest to may: not, a, to, which, and, be, that, for,
# Nearest to as: and, the, in, to, for, are, all, of,
# Nearest to have: to, this, not, it, are, as, that, always,
# Nearest to mathematics: explicitly, recognized, theory, evidence, work, i, simply, basis,
# Nearest to bbc: branch, equivalent, viewed, youth, fans, factors, top, artists,
# Nearest to bible: studying, editions, introduced, conversely, departments, established, model, board,
# Nearest to running: s, late, popular, state, development, success, several, national,
# Nearest to event: all, a, when, of, it, still, in, what,
# Nearest to freedom: world, were, and, to, for, some, being, of,
# Nearest to pressure: number, changes, over, much, degree, all, about, are,
# Nearest to stage: on, other, developed, course, for, there, people, the,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 6.1613 0.0161 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 5.8908 0.0151 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 6.0791 0.0151 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 5.9806 0.0153 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 5.8742 0.0151 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 5.9286 0.0152 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 5.9394 0.0151 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 5.9329 0.0151 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 5.9330 0.0045 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 5.8779 0.0152 sec/batch
# Nearest to often: be, way, particular, are, or, to, that, however,
# Nearest to time: in, and, on, of, the, as, this, a,
# Nearest to has: the, to, being, that, and, as, with, have,
# Nearest to during: until, the, and, in, had, to, by, time,
# Nearest to an: that, to, in, and, or, but, have, a,
# Nearest to may: that, but, not, would, it, change, to, for,
# Nearest to as: by, the, in, and, for, has, on, both,
# Nearest to have: to, or, are, however, not, has, a, and,
# Nearest to mathematics: theory, given, problems, an, so, a, once, knowledge,
# Nearest to bbc: day, november, listing, appointed, also, remaining, elected, state,
# Nearest to bible: studying, name, established, plans, beliefs, conversely, named, departments,
# Nearest to running: run, down, begin, for, which, line, high, system,
# Nearest to event: later, in, did, had, follow, to, limited, which,
# Nearest to freedom: by, being, in, the, he, world, and, since,
# Nearest to pressure: power, than, important, high, are, sometimes, maximum, large,
# Nearest to stage: of, soon, which, time, to, re, he, allowed,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 5.8995 0.0160 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 5.8604 0.0152 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 5.7880 0.0152 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 5.8844 0.0152 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 5.7581 0.0151 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 5.7289 0.0152 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 5.7569 0.0151 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 5.7501 0.0151 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 5.7062 0.0152 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 5.5408 0.0152 sec/batch
# Nearest to often: is, be, more, or, which, are, another, such,
# Nearest to time: the, on, in, with, to, at, as, all,
# Nearest to has: in, of, the, their, to, a, this, and,
# Nearest to during: the, by, in, from, most, world, after, was,
# Nearest to an: the, of, to, in, a, it, as, on,
# Nearest to may: the, or, such, to, has, a, no, an,
# Nearest to as: a, in, the, to, with, of, been, they,
# Nearest to have: as, to, any, that, this, the, is, it,
# Nearest to mathematics: formal, theory, explicitly, important, model, differ, consider, statement,
# Nearest to bbc: met, released, november, state, decades, commercial, service, promoting,
# Nearest to bible: christian, books, old, moreover, book, religions, text, editions,
# Nearest to running: run, at, to, just, available, on, up, end,
# Nearest to event: in, on, as, with, far, of, this, they,
# Nearest to freedom: many, in, and, since, from, on, their, of,
# Nearest to pressure: higher, are, low, types, easily, all, number, lead,
# Nearest to stage: they, with, as, or, a, on, that, the,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 5.6141 0.0160 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 5.6836 0.0150 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 5.7186 0.0152 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 5.6549 0.0151 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 5.5672 0.0152 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 5.5927 0.0151 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 5.5952 0.0151 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 5.6481 0.0151 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 5.5074 0.0152 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 5.5278 0.0154 sec/batch
# Nearest to often: is, some, which, be, what, that, an, as,
# Nearest to time: and, the, on, a, to, with, all, of,
# Nearest to has: the, and, but, in, to, from, both, on,
# Nearest to during: were, had, the, by, led, to, until, first,
# Nearest to an: it, the, but, a, is, of, to, for,
# Nearest to may: is, cases, are, some, which, or, be, however,
# Nearest to as: to, for, and, some, with, the, that, it,
# Nearest to have: that, or, it, to, a, they, these, but,
# Nearest to mathematics: theory, study, then, is, formal, for, what, be,
# Nearest to bbc: uk, united, active, numerous, since, government, listing, state,
# Nearest to bible: christian, islam, texts, latter, testament, divine, editions, scholars,
# Nearest to running: run, on, up, and, the, with, better, time,
# Nearest to event: the, to, and, with, independent, on, it, has,
# Nearest to freedom: the, in, by, being, world, recently, from, since,
# Nearest to pressure: higher, amount, are, number, process, low, lower, is,
# Nearest to stage: when, the, and, replace, which, on, with, it,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 5.5336 0.0159 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 5.5192 0.0152 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 5.5274 0.0151 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 5.5586 0.0151 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 5.4090 0.0153 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 5.4387 0.0154 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 5.5177 0.0152 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 5.4213 0.0152 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 5.4294 0.0151 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 5.4515 0.0151 sec/batch
# Nearest to often: be, that, is, or, this, only, called, not,
# Nearest to time: an, for, a, most, on, it, with, the,
# Nearest to has: as, to, a, more, with, on, in, but,
# Nearest to during: of, were, had, in, until, again, was, the,
# Nearest to an: to, a, as, for, its, however, from, but,
# Nearest to may: that, be, not, this, is, a, or, to,
# Nearest to as: to, for, which, with, from, an, but, the,
# Nearest to have: not, that, same, more, be, is, these, which,
# Nearest to mathematics: mathematical, proof, formal, practical, work, theory, explicitly, analysis,
# Nearest to bbc: television, april, december, on, numerous, public, service, politics,
# Nearest to bible: christian, texts, christianity, biblical, testament, scholars, islam, religious,
# Nearest to running: top, on, run, successful, together, main, line, technical,
# Nearest to event: on, place, the, before, and, in, although, these,
# Nearest to freedom: rights, shared, to, in, by, from, as, legal,
# Nearest to pressure: amount, higher, can, gas, making, result, process, types,
# Nearest to stage: this, although, quite, special, like, s, frequently, live,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 5.4530 0.0160 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 5.3405 0.0151 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 5.3370 0.0151 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 5.3850 0.0151 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 5.3782 0.0152 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 5.3648 0.0151 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 5.5722 0.0151 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 5.2594 0.0152 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 5.4429 0.0149 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 5.4082 0.0151 sec/batch
# Nearest to often: be, more, such, any, is, can, like, quite,
# Nearest to time: over, all, would, to, and, for, but, the,
# Nearest to has: to, that, with, which, it, a, the, as,
# Nearest to during: states, was, after, of, union, continued, government, again,
# Nearest to an: to, a, all, the, as, that, in, this,
# Nearest to may: to, this, or, a, it, which, be, that,
# Nearest to as: the, which, a, that, their, would, to, these,
# Nearest to have: that, a, there, which, as, it, has, this,
# Nearest to mathematics: mathematical, analysis, proof, study, complete, theory, be, particular,
# Nearest to bbc: november, april, year, october, january, day, june, december,
# Nearest to bible: testament, christian, texts, religious, scholars, theology, divine, christ,
# Nearest to running: main, line, over, high, run, allow, down, several,
# Nearest to event: since, on, a, only, the, to, although, but,
# Nearest to freedom: rights, political, opponents, been, legal, deal, people, did,
# Nearest to pressure: lower, higher, relatively, damage, low, required, are, high,
# Nearest to stage: live, records, life, and, break, top, audience, room,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 5.2441 0.0161 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 5.3324 0.0151 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 5.2954 0.0151 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 5.3380 0.0151 sec/batch
# Epoch 5/10 Iteration: 18500 Avg. Training loss: 5.3445 0.0009 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 5.2737 0.0150 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 5.2756 0.0152 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 5.3385 0.0151 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 5.2311 0.0150 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 5.3066 0.0150 sec/batch
# Nearest to often: way, or, these, some, even, be, as, that,
# Nearest to time: for, a, the, on, few, when, has, as,
# Nearest to has: to, with, have, a, the, all, most, their,
# Nearest to during: became, began, was, after, the, from, over, powers,
# Nearest to an: a, to, all, has, no, is, that, what,
# Nearest to may: as, this, to, have, it, not, has, is,
# Nearest to as: with, no, to, the, a, this, have, which,
# Nearest to have: to, has, a, but, this, which, those, all,
# Nearest to mathematics: mathematical, study, set, theory, analysis, knowledge, real, consider,
# Nearest to bbc: august, year, april, february, march, day, listing, july,
# Nearest to bible: testament, christian, jesus, hebrew, texts, biblical, scholars, religious,
# Nearest to running: time, making, run, ran, line, better, for, enough,
# Nearest to event: on, the, to, a, having, all, rules, involved,
# Nearest to freedom: public, in, since, of, opposed, attempts, on, never,
# Nearest to pressure: higher, fixed, flow, high, due, resulting, lower, very,
# Nearest to stage: so, up, records, on, play, gets, a, show,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 5.2414 0.0159 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 5.1760 0.0152 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 5.2237 0.0152 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 5.2015 0.0152 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 5.2315 0.0151 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 5.0489 0.0151 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 5.1165 0.0151 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 5.1305 0.0151 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 5.1777 0.0150 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 5.1688 0.0151 sec/batch
# Nearest to often: it, be, sometimes, many, other, that, or, simply,
# Nearest to time: the, when, by, on, s, to, would, out,
# Nearest to has: of, and, including, become, to, important, still, it,
# Nearest to during: became, was, after, had, until, s, from, were,
# Nearest to an: a, as, it, or, to, same, be, for,
# Nearest to may: it, as, no, other, only, a, some, such,
# Nearest to as: a, only, for, the, to, it, many, no,
# Nearest to have: to, be, some, there, or, this, many, that,
# Nearest to mathematics: mathematical, logic, analysis, proof, theory, we, reference, study,
# Nearest to bbc: broadcasting, television, radio, uk, february, service, news, november,
# Nearest to bible: testament, hebrew, biblical, christian, book, texts, jesus, christ,
# Nearest to running: up, run, wide, start, passes, runs, down, line,
# Nearest to event: in, would, time, only, the, of, going, no,
# Nearest to freedom: public, the, promote, issue, in, since, rights, social,
# Nearest to pressure: amount, higher, occurs, flow, temperature, lower, material, types,
# Nearest to stage: up, on, shows, at, off, in, and, will,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 5.0805 0.0161 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 5.1223 0.0152 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 5.1330 0.0152 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 5.2048 0.0152 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 5.0958 0.0152 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 5.0410 0.0154 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 5.0806 0.0151 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 5.1036 0.0152 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 5.0604 0.0152 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 5.1254 0.0152 sec/batch
# Nearest to often: as, is, not, some, but, way, this, a,
# Nearest to time: on, a, for, with, through, to, than, most,
# Nearest to has: but, been, many, to, the, with, their, for,
# Nearest to during: the, of, had, before, until, and, throughout, in,
# Nearest to an: be, a, with, is, that, to, not, because,
# Nearest to may: it, is, to, not, some, that, or, as,
# Nearest to as: some, is, a, that, which, other, this, it,
# Nearest to have: are, other, or, it, is, many, this, which,
# Nearest to mathematics: mathematical, analysis, logic, study, proof, theory, sets, theoretical,
# Nearest to bbc: television, selling, radio, successful, on, s, uk, tv,
# Nearest to bible: testament, biblical, hebrew, christian, scholars, jewish, scripture, jesus,
# Nearest to running: run, up, release, long, getting, game, down, third,
# Nearest to event: time, with, position, a, to, the, actually, this,
# Nearest to freedom: social, rights, since, opposed, the, in, issue, society,
# Nearest to pressure: occurs, amount, temperature, heat, phase, flow, surface, are,
# Nearest to stage: made, success, appeared, recorded, on, up, original, shows,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 5.0013 0.0159 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.9958 0.0152 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 5.1010 0.0151 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 5.0215 0.0152 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 5.0439 0.0152 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 5.0640 0.0153 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 5.0651 0.0150 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.9179 0.0151 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.9690 0.0151 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.9624 0.0151 sec/batch
# Nearest to often: be, more, are, different, such, is, some, example,
# Nearest to time: a, on, since, to, which, made, as, the,
# Nearest to has: to, as, since, are, for, more, either, a,
# Nearest to during: were, had, of, the, in, and, been, under,
# Nearest to an: a, that, being, for, it, the, to, this,
# Nearest to may: as, to, only, or, they, this, that, these,
# Nearest to as: for, on, the, which, to, may, seen, include,
# Nearest to have: it, to, these, that, or, this, which, such,
# Nearest to mathematics: mathematical, proof, logic, theory, analysis, solve, knowledge, sets,
# Nearest to bbc: april, external, year, december, february, june, collaboration, uk,
# Nearest to bible: testament, biblical, scholars, texts, christianity, christian, hebrew, god,
# Nearest to running: run, track, high, open, single, a, broken, reach,
# Nearest to event: on, a, time, place, an, to, just, both,
# Nearest to freedom: own, accept, issue, those, social, people, society, the,
# Nearest to pressure: low, amount, temperature, occurs, phase, pressures, resulting, relatively,
# Nearest to stage: time, made, emerging, s, better, actually, most, having,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 5.0239 0.0161 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 5.0083 0.0151 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 5.1286 0.0151 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 5.0052 0.0152 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 4.9632 0.0150 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 5.0651 0.0150 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 4.9412 0.0152 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 4.9348 0.0152 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 4.9319 0.0152 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 4.9530 0.0153 sec/batch
# Nearest to often: be, more, should, some, or, these, do, are,
# Nearest to time: in, the, and, made, by, on, a, when,
# Nearest to has: to, its, the, which, most, from, as, also,
# Nearest to during: was, until, after, remained, had, becoming, were, of,
# Nearest to an: a, to, in, and, this, that, they, as,
# Nearest to may: not, without, as, this, a, have, these, they,
# Nearest to as: they, to, in, most, the, both, a, which,
# Nearest to have: these, a, they, to, that, are, than, this,
# Nearest to mathematics: mathematical, theory, analysis, proof, logic, follows, reasoning, we,
# Nearest to bbc: june, february, april, listing, march, day, january, december,
# Nearest to bible: testament, biblical, texts, scholars, theology, jesus, book, scripture,
# Nearest to running: run, designed, for, added, release, down, system, only,
# Nearest to event: again, the, before, saw, s, although, would, at,
# Nearest to freedom: seek, legal, issue, political, among, establish, argued, rejected,
# Nearest to pressure: maximum, atmospheric, flow, low, temperature, liquid, higher, pressures,
# Nearest to stage: worked, audience, best, recording, playing, made, successful, hit,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 5.0078 0.0161 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 4.9224 0.0123 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 4.9444 0.0154 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 4.9589 0.0151 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 4.9106 0.0152 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 4.9317 0.0152 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 4.9445 0.0152 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 4.8176 0.0152 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 4.9398 0.0151 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 4.9044 0.0152 sec/batch
# Nearest to often: more, which, should, because, this, such, or, have,
# Nearest to time: at, on, a, the, to, all, for, first,
# Nearest to has: to, and, since, been, with, in, the, however,
# Nearest to during: after, the, until, was, in, been, and, place,
# Nearest to an: a, which, to, and, the, as, this, but,
# Nearest to may: not, this, some, only, no, which, have, to,
# Nearest to as: the, to, and, a, which, it, in, of,
# Nearest to have: to, which, any, all, more, not, is, a,
# Nearest to mathematics: mathematical, logic, theory, analysis, abstract, proof, mathematicians, define,
# Nearest to bbc: news, website, february, uk, march, television, december, new,
# Nearest to bible: testament, biblical, book, hebrew, texts, christian, scholars, jesus,
# Nearest to running: up, run, get, added, designed, just, line, extra,
# Nearest to event: in, was, at, to, time, the, previous, a,
# Nearest to freedom: issue, political, social, public, involvement, seek, influence, legal,
# Nearest to pressure: flow, low, temperature, atmospheric, surface, heating, lower, increases,
# Nearest to stage: made, cover, popular, up, re, achieved, at, on,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 4.9011 0.0160 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 4.7801 0.0154 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 4.7599 0.0152 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 4.8034 0.0151 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 4.8519 0.0151 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 4.8801 0.0151 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 4.7890 0.0152 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 4.8658 0.0153 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 4.8083 0.0152 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 4.8898 0.0152 sec/batch
# Nearest to often: some, it, a, have, as, this, may, that,
# Nearest to time: on, a, the, to, special, for, with, out,
# Nearest to has: to, it, and, some, but, no, as, other,
# Nearest to during: after, were, until, had, remained, was, occurred, began,
# Nearest to an: a, for, of, it, as, the, no, has,
# Nearest to may: no, it, some, as, not, have, other, because,
# Nearest to as: it, to, some, no, the, a, but, that,
# Nearest to have: some, it, that, no, which, not, even, may,
# Nearest to mathematics: mathematical, analysis, logic, theory, elementary, abstract, geometry, real,
# Nearest to bbc: uk, news, programme, march, october, november, february, radio,
# Nearest to bible: testament, biblical, christian, texts, scholars, hebrew, theology, christ,
# Nearest to running: up, fast, on, run, designed, target, switch, providing,
# Nearest to event: both, before, the, in, time, most, since, it,
# Nearest to freedom: political, social, rights, seek, grounds, policies, issue, society,
# Nearest to pressure: atmospheric, flow, increases, temperature, heat, surface, cooling, thermal,
# Nearest to stage: a, time, up, popular, on, created, short, back,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 4.8517 0.0160 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 4.7243 0.0151 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 4.7950 0.0150 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 4.8211 0.0151 sec/batch
# ...
# Nearest to stage: box, performance, crew, better, shooting, cover, quickly, versatile,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 4.2848 0.0160 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 4.3111 0.0152 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 4.2769 0.0150 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 4.3329 0.0150 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 4.3547 0.0150 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 4.2940 0.0150 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 4.3286 0.0150 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 4.3412 0.0150 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 4.3919 0.0150 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.3252 0.0150 sec/batch
# Nearest to often: such, some, or, which, may, sometimes, as, rather,
# Nearest to time: while, the, another, to, on, a, for, only,
# Nearest to has: to, other, both, there, in, of, and, generally,
# Nearest to during: after, months, were, finally, until, shortly, becoming, leaving,
# Nearest to an: a, to, of, is, this, for, another, which,
# Nearest to may: some, or, rather, this, not, be, are, have,
# Nearest to as: a, to, some, both, it, and, other, for,
# Nearest to have: or, there, some, are, those, than, may, these,
# Nearest to mathematics: mathematical, calculus, mathematicians, theory, geometry, analysis, logic, elementary,
# Nearest to bbc: news, television, uk, radio, broadcasting, march, programme, tv,
# Nearest to bible: testament, tanakh, biblical, hebrew, texts, christian, scriptures, torah,
# Nearest to running: run, backup, runs, track, game, ran, home, video,
# Nearest to event: the, about, last, away, while, events, going, previous,
# Nearest to freedom: rights, political, freedoms, promoting, social, policy, self, policies,
# Nearest to pressure: heat, flow, thermal, atmospheric, temperature, pressures, resulting, energy,
# Nearest to stage: featuring, box, success, studio, debut, appeared, featured, filming,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 4.2865 0.0159 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 4.3127 0.0151 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 4.3777 0.0151 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 4.3001 0.0151 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.3476 0.0150 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.3212 0.0152 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 4.2570 0.0151 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 4.3390 0.0151 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.3373 0.0152 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.3252 0.0153 sec/batch
# Nearest to often: some, such, as, only, simply, be, exclusively, sometimes,
# Nearest to time: with, out, it, a, on, first, up, so,
# Nearest to has: other, most, its, over, since, through, on, significant,
# Nearest to during: after, becoming, until, were, of, was, led, began,
# Nearest to an: a, with, this, which, as, for, to, that,
# Nearest to may: this, that, be, or, not, because, to, it,
# Nearest to as: to, some, which, although, this, with, it, being,
# Nearest to have: it, not, being, these, because, that, their, be,
# Nearest to mathematics: mathematical, calculus, theory, geometry, analysis, mathematicians, logic, theoretical,
# Nearest to bbc: news, television, uk, radio, listing, broadcasting, programmes, broadcasts,
# Nearest to bible: testament, tanakh, biblical, septuagint, christian, authorship, hebrew, scripture,
# Nearest to running: run, runs, ran, top, track, backup, highlights, unfortunately,
# Nearest to event: time, up, place, eleven, ever, events, ten, out,
# Nearest to freedom: promoting, rights, freedoms, social, self, political, issue, criticized,
# Nearest to pressure: atmospheric, resulting, gas, pressures, temperature, heat, gases, amount,
# Nearest to stage: featuring, show, box, featured, cover, releases, minute, best,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 4.2869 0.0162 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.3339 0.0152 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 4.2306 0.0151 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 4.2586 0.0152 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.3107 0.0153 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 4.2755 0.0152 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.3605 0.0151 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.4524 0.0150 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.2994 0.0150 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 4.2544 0.0150 sec/batch
# Nearest to often: some, simply, many, rather, such, common, particular, generally,
# Nearest to time: the, in, first, on, at, into, with, and,
# Nearest to has: other, been, most, and, largely, due, the, are,
# Nearest to during: was, had, until, leading, war, took, after, continued,
# Nearest to an: a, to, for, this, the, by, as, in,
# Nearest to may: any, this, that, be, certain, not, or, an,
# Nearest to as: to, and, the, many, it, most, been, have,
# Nearest to have: it, being, that, to, been, their, them, as,
# Nearest to mathematics: mathematical, mathematicians, calculus, analysis, thesis, foundations, theoretical, theory,
# Nearest to bbc: news, listing, radio, television, april, headline, itv, june,
# Nearest to bible: testament, biblical, tanakh, texts, scripture, torah, hebrew, scriptures,
# Nearest to running: run, track, runs, backup, top, ran, disappointing, single,
# Nearest to event: it, all, another, just, time, that, have, place,
# Nearest to freedom: rights, political, social, promoting, criticized, freedoms, liberties, movement,
# Nearest to pressure: pressures, resulting, atmospheric, explosions, gas, gases, stronger, shock,
# Nearest to stage: band, recording, cover, releases, audiences, footage, performances, camera,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 4.3341 0.0158 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 4.2485 0.0150 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 4.2459 0.0150 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 4.2642 0.0151 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.2733 0.0151 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.3518 0.0151 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 4.2660 0.0128 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 4.2679 0.0150 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 4.2883 0.0151 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.2747 0.0151 sec/batch
# Nearest to often: other, though, some, more, or, as, such, well,
# Nearest to time: a, on, up, at, in, first, to, few,
# Nearest to has: more, other, only, most, which, primarily, many, have,
# Nearest to during: began, was, war, took, becoming, until, had, became,
# Nearest to an: a, this, it, as, all, to, any, the,
# Nearest to may: not, or, be, such, an, than, no, certain,
# Nearest to as: an, it, although, a, most, all, some, in,
# Nearest to have: there, more, although, even, they, to, much, been,
# Nearest to mathematics: mathematical, mathematicians, textbook, geometry, calculus, analysis, theory, introductory,
# Nearest to bbc: listing, day, april, august, march, february, headline, gregorian,
# Nearest to bible: biblical, tanakh, testament, torah, verses, texts, scriptures, scholars,
# Nearest to running: run, runs, backup, handle, extra, screen, start, platform,
# Nearest to event: end, went, again, made, on, ever, previous, up,
# Nearest to freedom: political, social, rights, seek, movement, promote, issue, society,
# Nearest to pressure: gases, atmospheric, resulting, cooling, heating, heat, temperature, thermal,
# Nearest to stage: hit, crew, behind, down, breaking, gets, made, minute,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 4.2469 0.0160 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 4.3064 0.0150 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 4.1965 0.0152 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 4.2907 0.0151 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.2776 0.0150 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.3015 0.0150 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 4.2081 0.0152 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 4.1801 0.0151 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 4.2094 0.0150 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 4.2068 0.0150 sec/batch
# Nearest to often: sometimes, as, more, which, many, rather, that, a,
# Nearest to time: first, on, in, the, at, second, s, to,
# Nearest to has: as, for, the, have, its, many, in, most,
# Nearest to during: after, had, hundreds, were, immediately, until, massive, led,
# Nearest to an: it, as, a, the, between, is, this, in,
# Nearest to may: or, such, to, not, this, any, certain, be,
# Nearest to as: in, the, a, which, to, many, an, for,
# Nearest to have: to, as, or, there, some, the, generally, this,
# Nearest to mathematics: mathematical, mathematicians, calculus, textbook, logic, foundations, geometry, analysis,
# Nearest to bbc: news, radio, broadcasts, broadcasting, television, listing, website, itv,
# Nearest to bible: testament, book, tanakh, biblical, torah, hebrew, christian, texts,
# Nearest to running: run, up, runs, line, track, extra, backup, get,
# Nearest to event: only, reach, this, out, no, they, reached, to,
# Nearest to freedom: political, social, policies, promote, rights, democracy, organizing, criticism,
# Nearest to pressure: pressures, gases, heat, cooling, heating, atmospheric, thermal, temperature,
# Nearest to stage: show, appearance, featured, film, debut, successful, hit, featuring,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 4.2572 0.0159 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 4.2196 0.0150 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 4.2485 0.0150 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 4.2362 0.0150 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 4.2877 0.0150 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.2762 0.0152 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 4.1940 0.0151 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 4.2418 0.0152 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 4.2407 0.0152 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 4.2210 0.0151 sec/batch
# Nearest to often: many, as, sometimes, some, these, such, or, have,
# Nearest to time: the, for, a, on, it, this, another, with,
# Nearest to has: been, to, the, other, since, but, between, have,
# Nearest to during: until, after, continued, months, massive, remained, began, leaving,
# Nearest to an: is, a, be, for, number, it, with, to,
# Nearest to may: be, cases, to, there, because, have, not, or,
# Nearest to as: some, well, it, other, most, often, many, this,
# Nearest to have: there, or, it, because, being, this, other, is,
# Nearest to mathematics: mathematical, analysis, calculus, mathematicians, geometry, textbook, differential, theorems,
# Nearest to bbc: news, broadcasting, broadcasts, listing, tv, radio, broadcast, april,
# Nearest to bible: testament, tanakh, biblical, authorship, hebrew, septuagint, scriptures, christian,
# Nearest to running: run, ran, track, runs, backup, boot, game, competitors,
# Nearest to event: impact, time, events, while, end, ever, through, have,
# Nearest to freedom: social, principles, criticism, rights, policies, political, criticized, welfare,
# Nearest to pressure: temperature, flow, resulting, heat, gases, atmospheric, pressures, cooled,
# Nearest to stage: debut, appearance, featuring, success, performers, album, songs, filming,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 4.2353 0.0159 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.2240 0.0150 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 4.1937 0.0152 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.2397 0.0149 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 4.2498 0.0150 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 4.2154 0.0150 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 4.2134 0.0150 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 4.2309 0.0149 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 4.1552 0.0149 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 4.1831 0.0149 sec/batch
# Nearest to often: such, well, or, specifically, some, different, even, many,
# Nearest to time: another, first, up, a, out, which, way, that,
# Nearest to has: as, have, most, and, which, for, other, with,
# Nearest to during: were, after, continued, occurred, leaving, forced, remained, until,
# Nearest to an: a, is, this, number, for, which, any, by,
# Nearest to may: to, cases, not, however, that, certain, any, have,
# Nearest to as: the, have, such, more, of, although, which, some,
# Nearest to have: this, which, that, not, to, the, as, more,
# Nearest to mathematics: mathematical, calculus, mathematicians, foundations, analysis, geometry, theorems, logic,
# Nearest to bbc: news, television, itv, april, headline, weekly, abc, listing,
# Nearest to bible: tanakh, testament, biblical, septuagint, authorship, hebrews, prophetic, scriptures,
# Nearest to running: run, ran, newer, runs, connect, track, platform, drivers,
# Nearest to event: events, time, about, have, impact, giving, place, yet,
# Nearest to freedom: political, rights, social, criticized, interests, policies, promoting, intellectual,
# Nearest to pressure: pressures, temperature, cooled, atmospheric, gases, heat, resulting, flow,
# Nearest to stage: performers, success, debut, show, performing, piece, roles, audience,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.2186 0.0158 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 4.1734 0.0151 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.2857 0.0150 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.2775 0.0151 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.3252 0.0150 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 4.1681 0.0152 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 4.2229 0.0150 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.2055 0.0150 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 4.1484 0.0151 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.1870 0.0151 sec/batch
# Nearest to often: some, even, similar, more, such, quite, or, rather,
# Nearest to time: on, the, to, was, made, with, from, end,
# Nearest to has: been, although, than, and, the, also, are, its,
# Nearest to during: after, forced, had, became, was, war, took, becoming,
# Nearest to an: a, and, where, is, for, to, this, such,
# Nearest to may: cases, however, to, not, should, least, this, certain,
# Nearest to as: in, and, for, to, been, the, other, many,
# Nearest to have: than, this, to, because, these, has, for, such,
# Nearest to mathematics: mathematical, mathematicians, analysis, geometry, foundations, theorems, calculus, thesis,
# Nearest to bbc: listing, anniversary, june, news, headline, day, april, january,
# Nearest to bible: tanakh, testament, texts, translations, septuagint, hebrew, biblical, translation,
# Nearest to running: run, line, runs, drivers, next, track, ran, window,
# Nearest to event: happened, events, would, accomplishments, impact, before, place, about,
# Nearest to freedom: rights, social, public, movement, promote, political, issues, liberties,
# Nearest to pressure: cooled, resulting, effect, gas, atmospheric, pressures, gases, temperature,
# Nearest to stage: performances, performers, appearances, show, audience, band, debut, films,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.2089 0.0158 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 4.2301 0.0151 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
